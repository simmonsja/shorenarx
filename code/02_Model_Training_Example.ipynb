# %% [markdown]
# # Shoreline NARX Model Training Example
# Joshua Simmons and Kristen Splinter
#
# In this notebook, an example is given of how to train a model on the available shoreline data using the NARX model. Results for the publication are generated by running the script 02a_CV_Run_Script.py which saves the fitted models for analysis and plotting.

# %%
# magic
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys, os, re
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from shoreNARX import TrainingClass
from shoreNARX.plotting import plot_CV_ensemble

# %% [markdown]
# ## Specify the model configuration
# Load the model configuration from a config (json) file. Use the TrainingClass methods to load the correct data in the correct format.

# %%
baseLoc = '.'
# First train Narra
narraConfigFile = os.path.join(baseLoc,'config','narra_base_config.json')
# init object
trainObj_narra = TrainingClass(**{'baseDir':baseLoc,'config':narraConfigFile})
# train as per config
trainObj_narra.load_cv_test()
# Load Tairua
tairuaConfigFile = os.path.join(baseLoc,'config','tairua_base_config.json')
# init object
trainObj_tairua = TrainingClass(**{'baseDir':baseLoc,'config':tairuaConfigFile})
# train as per config
trainObj_tairua.load_cv_test()

# %% [markdown]
# ## Train models
# This is just for demonstration and testing. Due to computational demands, the model training is done using the `02a_CV_Run_Script.py` file.

# %%
baseLoc = '.'

def train_run(configFile,return_class=False,saveBool=False):
    # init object
    trainObj = TrainingClass(**{'baseDir':baseLoc,'config':configFile})
    if return_class:
        return trainObj
    # train as per config
    res = trainObj.training_wrapper(saveBool=saveBool)
    print(res)
    return trainObj

# %%
# First train Narra
narraConfigFile = os.path.join(baseLoc,'config','narra_sattest1_config.json')
narra_trained = train_run(narraConfigFile)
# Out:
# Epoch 17/1000 - Loss: 6.53:   2%|▏         | 17/1000 [00:15<14:53,  1.10it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # First train Narra
#       2 narraConfigFile = os.path.join(baseLoc,'config','narra_sattest1_config.json')
# ----> 3 narra_trained = train_run(narraConfigFile)
#
# Cell In[4], line 9, in train_run(configFile, return_class, saveBool)
#       7     return trainObj
#       8 # train as per config
# ----> 9 res = trainObj.training_wrapper(saveBool=saveBool)
#      10 print(res)
#      11 return trainObj
#
# File /project/code/shoreNARX/analysis_class.py:429, in TrainingClass.training_wrapper(self, saveBool)
#     427 statsOut = []
#     428 for thisComb in self.trainCombs:
# --> 429     statsOut.append(self.cv_Instance(thisComb, settings=modelSettings))
#     431 if saveBool:
#     432     savePath = os.path.join(
#     433         self.baseDir,'results','models',
#     434         'case_' + self.config['saveClass'],
#    (...)
#     439         )
#     440     )
#
# File /project/code/shoreNARX/analysis_class.py:277, in TrainingClass.cv_Instance(self, ttComb, settings)
#     275 # train the model
#     276 shorelineModel.initialise_model(**settings)
# --> 277 model, bestEpoch, trainStats = shorelineModel.train(**settings)
#     279 df_testingdata = {
#     280     'test': {
#     281         'obsY': pd.DataFrame(data=cvData['testY'],
#    (...)
#     306     'testR': trainStats[6],
#     307 }
#     309 return df_testingdata
#
# File /project/code/shoreNARX/model_class.py:140, in ShorelineMLModel.train(self, **settings)
#     138 truepred = torch.rand(thisbatch_x.shape[0])
#     139 for ii, thisx in enumerate(thisbatch_x):
# --> 140     newx = self.pytorch_norm_data(dummyNorm, prevx)
#     141     pred = model(torch.cat((thisx[:-1],torch.Tensor(newx[-1])),dim=0))
#     143     if settings.get('dx',True):
#
# File /project/code/shoreNARX/model_class.py:315, in ShorelineMLModel.pytorch_norm_data(self, thisX, xhold)
#     313 #replace the previous shoreline position with the normalised value
#     314 thisX[-1] = xhold.detach().numpy()
# --> 315 normold = self.scalerX.transform(thisX.T).T
#     316 thisX[-1] = normold[-1]
#     317 return thisX
#
# File /build/miniconda3/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File /build/miniconda3/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:1004, in StandardScaler.transform(self, X, copy)
#    1001 check_is_fitted(self)
#    1003 copy = copy if copy is not None else self.copy
# -> 1004 X = self._validate_data(
#    1005     X,
#    1006     reset=False,
#    1007     accept_sparse="csr",
#    1008     copy=copy,
#    1009     dtype=FLOAT_DTYPES,
#    1010     force_all_finite="allow-nan",
#    1011 )
#    1013 if sparse.issparse(X):
#    1014     if self.with_mean:
#
# File /build/miniconda3/lib/python3.10/site-packages/sklearn/base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File /build/miniconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:759, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     752 if isinstance(array, np.matrix):
#     753     raise TypeError(
#     754         "np.matrix is not supported. Please convert to a numpy array with "
#     755         "np.asarray. For more information see: "
#     756         "https://numpy.org/doc/stable/reference/generated/numpy.matrix.html"
#     757     )
# --> 759 xp, is_array_api_compliant = get_namespace(array)
#     761 # store reference to original array to check if copy is needed when
#     762 # function returns
#     763 array_orig = array
#
# KeyboardInterrupt:

# %%
pd.DataFrame(narra_trained.trainCombsGenerate(10,2,rs=1))

# %%
# Then Tiarua
tairuaConfigFile = os.path.join(baseLoc,'config','tairua_base_config.json')
tairua_trained = train_run(tairuaConfigFile)

# %% [markdown]
# # Show model performance

# %%
for thisFold in np.arange(narra_trained.statsOut[0].__len__()):
    plot_CV_ensemble(
        narra_trained.statsOut,
        thisFold
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for thisFold in np.arange(narra_trained.statsOut[0].__len__()):
#       2     plot_CV_ensemble(
#       3         narra_trained.statsOut,
#       4         thisFold
#       5     )
#
# AttributeError: 'TrainingClass' object has no attribute 'statsOut'

# %%
for thisFold in np.arange(narra_trained.statsOut[0].__len__()):
    plot_CV_ensemble(
        tairua_trained.statsOut,
        thisFold
    )
